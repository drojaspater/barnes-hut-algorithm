# %%
from copy import deepcopy
from numpy import array, empty, sqrt, arange, zeros, cross
from numpy.linalg import norm
from numpy import random
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
class Node:
# Un nodo representa un cuerpo si es un nodo final (es decir, si node.child es None)
# o un nodo abstracto del árbol cuádruple si tiene un hijo.

    def __init__(self, m, r, p):
        # El inicializador crea un nodo sin hijos (un cuerpo real).
        self.m = m  #Masa del cuerpo
        
        # En lugar de almacenar la posición de un nodo, almacenamos los tiempos de masa
        # posición, m_pos. Esto facilita la actualización del centro de masa.
        self.m_pos    = m * array(r) 
        self.momentum = array(p) 
        
        #Estamos indicando que esto es el nodo final y debemos acomodarlo
        self.child = None

    def into_next_quadrant(self):
    # Coloca el nodo en el cuadrante del siguiente nivel y devuelve el número de cuadrante.
    
        # s: longitud lateral del cuadrante actual
        self.s = 0.5 * self.s  
        
        # Se hace la división en y y en x, para posteriormente obtener el cuadrante
        return self._subdivide(1) + 2*self._subdivide(0) #El 2 nos da conteo de la columna

    def velocity(self):
    # Returns the physical velocity of the node.
        return self.momentum / self.m
    
    def pos(self):
    # Posición física del nodo, independiente del cuadrante actualmente activo.
        return self.m_pos / self.m

    def reset_to_0th_quadrant(self):
    # Reubica el nodo en el cuadrante de nivel 0 (dominio completo).
    
        # La longitud lateral del cuadrante de nivel 0.
        self.s = 60.
        
        # La posición relativa dentro del cuadrante es igual a la posición física.
        self.relpos = self.pos().copy()

    def dist(self, other):
    # Distancia entre el nodo actual y otro nodo.
        return norm(other.pos() - self.pos())

    def force_on(self, other):
    # Fuerza que ejerce el nodo actual sobre un cuerpo dado.
    
        ## Esto nos permite hacer correcciónes a distancias cortas
        cutoff_dist = 0.002*60
        d = self.dist(other)
        if d < cutoff_dist:
            return array([0., 0.]) #No hay fuerza cuando los cuerpos estan muy cerca 
        else:
            # La fuerza gravitatoria va como 1/r**2.
            return (self.pos() - other.pos()) * (self.m*other.m / d**3)
        
    def potential_forc(self, other):
    #Energia potencial debido a la interacción con otro cuerpo
                ## Esto nos permite hacer correcciónes a distancias cortas
        cutoff_dist = 0.002*60
        d = self.dist(other)
        if d < cutoff_dist:
            return 0. #No hay fuerza y por ende no energia potencial
        else:
            # La fuerza gravitatoria va como 1/r**2.
            return -(self.m*other.m / d)

    def _subdivide(self, i):
    # Coloca el nodo en el cuadrante del siguiente nivel a lo largo de la dirección i y vuelve a calcular
    # la posición relativa relpos del nodo dentro de este cuadrante.
        self.relpos[i] *= 2.0
        if self.relpos[i] < 60.0:
            quadrant = 0
        else:
            quadrant = 1
            self.relpos[i] -= 60.0  #Normaliza la posición relativa al restar la longitud del primer cuadrante
        return quadrant

# %%
def add(body, node):
    '''Barnes-Hut algorithm: Creación del árbol cuadruple. Esta función añande
       un nuevo cuerpo en el nodo del árbol cuadruple. Devuelve una versión actualizada del nodo.
       body: Objeto de clase nodo
       node: cuadrante del nodo
    '''
# Barnes-Hut algorithm: Creación del árbol cuadruple. Esta función añande 
# un nuevo cuerpo en el nodo del árbol cuadruple. Devuelve una versión actualizada del nodo.

    # 1. Si el nodo n no contiene un cuerpo, coloque el nuevo cuerpo b aquí.
    ## Si node es None, es decir, si tenemos el nodo final, se toma la información de body
    ## En otro caso, se deja una variable tipo NoneType
    new_node = body if node is None else None  
    
    # Para limitar la profundidad de recursión, establezca un límite inferior para el tamaño del cuadrante.
    # Objetos dentro de este cuadrante se consideran iguales
    smallest_quadrant = 60*1.e-4 ## Cuadrante más pequeño, cambiar a unidades astronomicas
    
    if node is not None and node.s > smallest_quadrant:
        # 3. Si el nodo n es un nodo externo, entonces el nuevo cuerpo b está en conflicto
        # con un cuerpo ya presente en esta región
        if node.child is None: 
            new_node = deepcopy(node)
        # ... Subdividir aún más la región creando cuatro hijos
            new_node.child = [None for i in range(4)] #Creación de una nueva rama del arbol
        # ... Y para empezar, inserte recursivamente el cuerpo ya presente
        # en el cuadrante apropiado.
            quadrant = node.into_next_quadrant() #Esto nos devuelve el cuadrante siguiente
            new_node.child[quadrant] = node
            
        # 2. Si el nodo n es un nodo interno, no debemos modificar su hijo.
        else:
            new_node = node

        # 3. Si el nodo n es o se ha convertido en un nodo interno...
        # ... actualice su masa y "centro de masa por masa".
        new_node.m += body.m
        new_node.m_pos += body.m_pos
        # ... y agrega recursivamente el nuevo cuerpo en el cuadrante apropiado.
        # El proceso de recursividad termina cuando el cuerpo se encuentra en el nodo final
        quadrant = body.into_next_quadrant()
        new_node.child[quadrant] = add(body, new_node.child[quadrant]) 
    return new_node

# %%
def force_on(body, node, theta):
    '''Algoritmo de Barnes-Hut: uso del quad-tree. Esta función calcula
       la fuerza neta sobre un cuerpo ejercida por todos los cuerpos en el nodo "nodo".
       Tenga en cuenta cómo el código es más corto y más expresivo que el lenguaje humano
       body: Objeto de clase nodo
       node: cuadrante del nodo
       theta: termino de distancia despreciable
       '''
    #descripción del algoritmo.
    # 1. Si el nodo actual es un nodo externo,
    # calcular la fuerza ejercida por el nodo actual en b.
    if node.child is None:
        return node.force_on(body)

    # 2. De lo contrario, calcula la relación s/d. Si s/d < θ (criterio de distancia),  
    # trate este nodo interno como un solo cuerpo, y calcule la fuerza que ejerce sobre el cuerpo b.
    if node.s < node.dist(body) * theta:
        return node.force_on(body)

    # 3. De lo contrario, ejecute el procedimiento recursivamente en cada hijo.
    return sum(force_on(body, c, theta) for c in node.child if c is not None)

# %%
def potential_energy(body, node, theta):
    '''Algoritmo de Barnes-Hut: uso del quad-tree. Esta función calcula
       la energia potencial neta de un cuerpo en el sistema.
       Tenga en cuenta cómo el código es más corto y más expresivo que el lenguaje humano
       body: Objeto de clase nodo
       node: cuadrante del nodo
       theta: termino de distancia despreciable
       '''
    #descripción del algoritmo.
    # 1. Si el nodo actual es un nodo externo,
    # calcular la fuerza ejercida por el nodo actual en b.
    if node.child is None:
        return node.potential_forc(body)

    # 2. De lo contrario, calcula la relación s/d. Si s/d < θ (criterio de distancia),  
    # trate este nodo interno como un solo cuerpo, y calcule la fuerza que ejerce sobre el cuerpo b.
    if node.s < node.dist(body) * theta:
        return node.potential_forc(body)

    # 3. De lo contrario, ejecute el procedimiento recursivamente en cada hijo.
    return sum(potential_energy(body, c, theta) for c in node.child if c is not None)

# %%
def verlet(bodies, root, theta, G, dt):
    '''Ejecute una iteración de tiempo según el algoritmo de Verlet.
       bodies: Lista de objetos de clase node
       root: cuadrante del arbol
       theta: termino de disntacia despreciable
       G: Constante de gravitación en unidades adecuadas
       dt: paso del algoritmo'''

    for body in bodies:
        force = G * force_on(body, root, theta)
        body.momentum += dt * force
        body.m_pos += dt * body.momentum

# %%
def random_generate(N, center, ini_radius, M, mi, mf):
    '''
     Esta función genera de forma aleatoria el sistema de N cuerpos
     con una distribución de velocidad inicial keplereana que simula
     un sistema de estrellas girando en torno a un agujero negro super masivo
     La función pide de entrada:
     N: Número de moleculas.
     Center: Centro del sistema de particulas.
     ini_radius: Radio de la galaxia.
     M: Masa del agujero negro supermasivo.
     mi: Masa minima de las estrellas.
     mf: Masa maxima de las estrellas.
     La función retorna una lista con las masas de los cuerpos, las posiciónes inciciales 
     y las velocidades inciales.
    '''
    
    # Generaremos K=2*N cuerpos aleatorios para posteriormente escoger
    # N cuerpos dentro de un circulo de radio ini_radius
    K =2*N
    random.seed(413)
    positions = empty([N,2])
    momenta = empty([N,2])

    #Se crea un arreglo vacío de tamaño N para las masas
    mass = empty([N])
    #Se adiciona la masa del agujero negro super masivo
    mass[0] = M

    # Se generan los valores de masa aleatorios entre dos valores (mi,mf) 
    # que entran a la función
    
    for i in range(N-1):
      mass[i+1] =  random.uniform(mi,mf)

    # las posicions x, y se generan dentro del cuadrado 
    # de lado L = 2*ini_radius.
    posx = random.random(K) *2.*ini_radius + center[0]-ini_radius
    posy = random.random(K) *2.*ini_radius + center[1]-ini_radius
    i = 0
    j = 0
    #Loop hasta completar los N cuerpos aleatorios o usar los K cuerpos generados
    while i<K and j<N:
        position = array([posx[i],posy[i]])
        r = position - center
        norm_r = sqrt(r.dot(r))
        if norm_r < ini_radius:
            positions[j] = position
            # Momentum angular donde v = w x r = (-yi + xj)*Omega 
            # Omega es la velocidad angular Kepleriana
            momenta[j] = mass[j]*array([-r[1], r[0]])*sqrt((G*M)/(norm_r**3))
            j += 1
        i += 1

    positions[0] = center
    momenta[0] = [0,0]
    return mass, positions, momenta

# %%
def system_init(N, center, ini_radius, M, mi, mf):
    '''
     Esta función inicializa el sistema de N-cuerpos definiendo aleatoriamente
     los vectores de posición de los cuerpos y creando los correspondientes
     objetos de la clase Nodo
     N: Número de moleculas.
     Center: Centro del sistema de particulas.
     ini_radius: Radio de la galaxia.
     M: Masa del agujero negro supermasivo.
     mi: Masa minima de las estrellas.
     mf: Masa maxima de las estrellas.
    '''
    bodies = []
    mass, positions, momenta = random_generate(N, center, ini_radius, M, mi, mf)
    for i in range(N):
      #Agregamos el arreglo de la masa y sus respectivos parámetros a la función
       bodies.append(Node(mass[i], positions[i], momenta[i]))
    return bodies

# %%
def plot_bodies(bodies, i):
    '''
    Escribe una imagen que represente la posición actual de los cuerpos.
    Para crear una película con avconv o ffmpeg use el siguiente comando:
    ffmpeg -r 15 -i cuerpos_%06d.png -q:v 0 cuerpos.avi 
    bodies: Lista de objetos de clase node
    '''
    ax = plt.gcf().add_subplot(111, aspect='equal')
    ax.cla()
    ax.scatter([b.pos()[0] for b in bodies], [b.pos()[1] for b in bodies], 1, color='darkred')
    ax.scatter(30.0,30.0,color='black',s=10)
    ax.set_xlim([0., 60.0])
    ax.set_ylim([0., 60.0])
    plt.gcf().savefig('/home/pater/Desktop/CosasPater/UNAL/2023-01OctavoSemestre/HerramientasComputacionales/BernesHut/Imagenes/bodies_{0:06}.png'.format(i))
    #plt.show()

# %%
######### Programa principal ########################################################

# Theta-criterio del algoritmo de Barnes-Hut.
theta = 0.5
# Masa agujero negro y masa maxima y minima
M  = 4e6
mi = 1
mf = 50
# Los cuerpos iniciales se distribuyen en un circulo de radio ini_radius.
ini_radius = 30
# La "constante gravitatoria" se elige para obtener una salida agradable.
G = 4.30091e-6
# Paso discreto.
##T = 1000000
##dt = 13e9/T
dt = 5.e-3 
# Número de cuerpos (el número real es menor, porque todos los cuerpos
# fuera del radio inicial se eliminan).
numbodies = 500#1000
# Número de iteraciones de tiempo ejecutadas por el programa.
max_iter = 1000
# Frecuencia con la que se escriben las imágenes PNG.
img_iter = 20
# Ubicación del agujero negro
center = [30,30]
# Lista de energias
Et = zeros(max_iter)
Kt = zeros(max_iter)
Ut = zeros(max_iter)
Lt = zeros(max_iter)


#Generación de los cuerpos
bodies = system_init(numbodies, center, ini_radius, M, mi, mf)

# %%
# Ciclo principal en iteraciones temporales.
for i in range(max_iter):
    # El árbol cuádruple se vuelve a calcular en cada iteración.
    root = None
    for body in bodies:
        body.reset_to_0th_quadrant()
        root = add(body, root)
    # Cómputo de fuerzas, y avance de cuerpos.
    verlet(bodies, root, theta, G, dt)
    # Output
    
    # Energia
    K = 0
    U = 0
    L = 0
    for body in bodies:
    # Recorro cada uno de los cuerpos para conocer su aporte de energia en el sistema
        # Energia cinitca
        K += norm(body.momentum)**2/(2*body.m)
        # Para acceder a la energia potencial debemo recorrer el arbol
        # Y considerar los aportes de los objetos que realizan fuerza en el sistema
        U += G * potential_energy(body, root, theta)
        
        L += cross(body.m_pos/body.m - array(center), body.momentum)
        
    #Agrego en arrays la energia en un tiempo i para tener acceso a las energias en el tiempo
    Et[i] = K + U
    Kt[i] = K
    Ut[i] = U
    Lt[i] = L
           
    #if i%img_iter==0:
        #print("Writing images at iteration {0}".format(i))
        #plot_bodies(bodies, i//img_iter)

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(arange(0,max_iter,1),(Et-Et[0])/Et[0],color='darkred',label=r'Energia total')
plt.plot(arange(0,max_iter,1),(Kt-Kt[0])/Kt[0],color='darkblue',label=r'Energia cinetica')
plt.plot(arange(0,max_iter,1),(Ut-Ut[0])/Ut[0],color='darkgreen',label=r'Energia potencial')
plt.title(r'Error relativo de la energia con respecto a la inical')
plt.ylabel(r'Energia')
plt.xlabel(r'$t$ en años')
plt.legend()

plt.subplot(1,2,2)
plt.plot(arange(0,max_iter,1),Et,color='darkred',label=r'Energia total')
plt.plot(arange(0,max_iter,1),Kt,color='darkblue',label=r'Energia cinetica')
plt.plot(arange(0,max_iter,1),Ut,color='darkgreen',label=r'Energia potencial')
plt.title(r'Energia en el tiempo')
plt.ylabel(r'Energia')
plt.xlabel(r'$t$ en años')
plt.legend()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(arange(0,max_iter,1),(Lt-Lt[0])/Lt[0],color='darkred')
#plt.title(r'Error relativo del momento angular con respecto a la inical')
plt.ylabel(r'Energia')
plt.xlabel(r'$t$ en años')
plt.legend()

plt.subplot(1,2,2)
plt.plot(arange(0,max_iter,1),Lt,color='darkred')
#plt.title(r'Momento angular en el tiempo')
plt.ylabel(r'Momento angular')
plt.xlabel(r'$t$ en años')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
Omega = np.zeros(len(bodies))
Dista = np.zeros(len(bodies))
for body in bodies:
    Vor =
# Out:
# array([30, 30])
